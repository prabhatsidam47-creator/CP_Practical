# %%
print("Shruti Sidam")
# Out:
# Shruti Sidam

# %%
name =(input('shruti sidam'))
print("Hello,", name, "! Welcome to the world of programming.")
# Out:
# Hello, xyz ! Welcome to the world of programming.

# %%
# StudentgradeA-above95marks,b-above85marks,c-above75marks,d-above65marks,e-above55marks,f-below55marks
